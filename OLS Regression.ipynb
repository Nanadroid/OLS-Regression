# %%
#pip install openpyxl
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
myfile = pd.read_excel(    'C:\\filepath.xlsx',    sheet_name=['Returns', 'Factors'])

# %%
for sheet_name, Factors in myfile.items():
     Factors['sheets'] = sheet_name    
    
export_csv = Factors.to_csv (r'Downloads',
                            index = None, header=True)
Factors.head()
# Out:
#     Month  Mkt-RF   SMB   HML    RF   sheets
# 0  201701    1.94 -1.06 -2.81  0.04  Factors
# 1  201702    3.57 -2.01 -1.79  0.04  Factors
# 2  201703    0.17  1.17 -3.33  0.03  Factors
# 3  201704    1.09  0.72 -2.11  0.05  Factors
# 4  201705    1.06 -2.61 -3.67  0.06  Factors

# %%
x1=Factors['Mkt-RF']
x2=Factors['SMB']
x3=Factors['HML']
e=np.random.randn(100,1)

# %%
type(myfile)
# Out:
# dict

# %%
y=myfile['Returns']['Return']
x=Factors[['RF','Mkt-RF','SMB','HML']]
x = sm.add_constant(x) 
model = sm.OLS(y, x)
model_res =model.fit()
model_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Return   R-squared:                       0.167
# Model:                            OLS   Adj. R-squared:                  0.091
# Method:                 Least Squares   F-statistic:                     2.204
# Date:                Sun, 06 Apr 2025   Prob (F-statistic):             0.0840
# Time:                        22:29:19   Log-Likelihood:                 40.997
# No. Observations:                  49   AIC:                            -71.99
# Df Residuals:                      44   BIC:                            -62.53
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1261      0.036      3.503      0.001       0.054       0.199
# ...

# %% [markdown]
# <font size="5">$$R^2=0.167$$
#
# $$b=0.1261$$
# </font>
